# %%
import selenium 
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r'C:\Users\admin\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.youtube.com')

# %%
video=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-grid-row[1]/div/ytd-rich-item-renderer[1]/div/ytd-rich-grid-media/div[1]/ytd-thumbnail/a/yt-image/img')
video.click()

# %%
driver.execute_script('window.scrollBy(0,500)')
Coment=[]
com=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="style-scope ytd-comment-renderer"]')
for i in com:
    a=i.text
    Coment.append(a)

# %%
len(Coment)
# Out:
# 637

# %%
Coment
# Out:
# ['Watch the trailer of the BIGGEST action spectacle of 2023 - https://youtu.be/vqu4z34wENw',
#  'No one can replace the heavenly voice of Arijit Singh',
#  "Literally when this this was played the theatre's was converted into stadium ",
#  'No one can ingnore Arijit Singh because his Voice direct touch our heart . Arijit Singh is the legend of Bollywood no anyone can ingnore his..',
#  'No one can replace the craze and hype created by Pathaan except another movie having Pathaan.',
#  'No one can replace the heavenly voice of Arijit Singh ',
#  'KING OF VOICE ARIJIT SINGH ️\nKING OF BOLLYWOOD SRK \nRARE COMBINATION ️',
#  'Arijit Is A Gem And The Combo Of SRK and Arijit Is Blockbuster And Chartbuster️',
#  'Arijit Singh is the backbone of Indian music ️\u200d',
#  'We can ignore bollywood but no one can ignore Arijit Singh . His voice is a blessing to our ears ️',
#  'No.1 trending in 8 hrs and 10 mn.+views. This is Insane ️',
# ...

# %%
driver.execute_script('window.scrollBy(0,500)')
Time=[]
times=driver.find_elements(By.XPATH,'//yt-formatted-string[@class="published-time-text style-scope ytd-comment-renderer"]')
for i in times:
    Time.append(i.text)

# %%
len(Time)
# Out:
# 657

# %%
Time[0:10]
# Out:
# ['3 weeks ago (edited)',
#  '1 month ago',
#  '1 day ago',
#  '2 days ago',
#  '18 hours ago',
#  '3 days ago',
#  '1 day ago (edited)',
#  '1 month ago',
#  '3 days ago',
#  '3 days ago']

# %%
driver.execute_script('window.scrollBy(0,500)')
Upvote=[]
vote=driver.find_elements(By.XPATH,'//ytd-comment-action-buttons-renderer[@class="style-scope ytd-comment-renderer"]')
for i in vote:
    a=i.text.split('\n')[0]
    Upvote.append(a)

# %%
len(Upvote)
# Out:
# 657

# %%
Upvote
# Out:
# ['8.1K',
#  '20K',
#  '125',
#  '740',
#  '147',
#  '386',
#  '347',
#  '4K',
#  '891',
#  '78',
#  '1.3K',
#  '136',
#  '9',
#  '4.8K',
#  '85',
#  '1',
#  '1.1K',
#  '302',
#  '3',
#  '470',
#  '6',
#  '58',
#  '2',
#  '281',
#  '6',
#  '257',
#  '78',
#  '82',
#  '330',
#  '97',
#  '8',
#  '3',
#  '6',
#  '7',
#  '27',
#  '5',
#  '679',
#  '60',
#  '6',
#  '5',
#  '6',
#  '291',
#  '25',
#  '5',
#  '7',
#  '5',
#  '200',
#  '5',
#  '88',
#  '3',
#  '86',
#  '3',
#  '152',
#  '3',
#  '2',
#  '4',
#  '127',
#  '1K',
#  '100',
#  '4',
#  '11',
#  '11',
#  '5',
#  '1',
#  '64',
#  '4',
#  '6',
#  '4',
#  '12',
#  '6',
#  '26',
#  '17',
#  '1',
#  '14',
#  '2',
#  '424',
#  '12',
#  '5',
#  '2',
#  '5',
#  '1',
#  '24',
#  '23',
#  '3',
#  '88',
#  '11',
#  'Reply',
#  '8',
#  '478',
#  '21',
#  '3',
#  '2',
#  '5',
#  '1',
#  '14',
#  '2',
#  '3',
#  '157',
#  '16',
#  '6',
#  '1',
#  '6',
#  '3',
#  '1.8K',
#  '1',
#  '4',
#  '1',
#  '17',
#  '3',
#  '148',
#  '14',
#  '1',
#  '4',
# ...

# %%
df=pd.DataFrame({})
df['Comment']=Coment[0:500]
df['TIME']=Time[0:500]
df['Upvote']=Upvote[0:500]

# %%
df
# Out:
#                                                Comment                  TIME  \
# 0    Watch the trailer of the BIGGEST action specta...  3 weeks ago (edited)
# 1    No one can replace the heavenly voice of Ariji...           1 month ago
# 2    Literally when this this was played the theatr...             1 day ago
# 3    No one can ingnore Arijit Singh because his Vo...            2 days ago
# 4    No one can replace the craze and hype created ...          18 hours ago
# ..                                                 ...                   ...
# 495                           Arijit Ne Tabahi Machadi           8 hours ago
# 496  This is called a versatile singer who sometime...           1 month ago
# 497       sharuk ji acting, honesty and hardwork super            3 days ago
# 498                           I love only insane Beat             3 days ago
# 499                  200 million views in just 1month              1 day ago
#
#     Upvote
# 0     8.1K
# 1      20K
# ...

# %%
driver.close()
